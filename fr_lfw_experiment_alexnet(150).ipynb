# %% [markdown]
# <a href="https://colab.research.google.com/github/Br-alexis73/Face_recognition/blob/master/fr_lfw_experiment_alexnet(150).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'lfw-dataset:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F26922%2F34595%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240419%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240419T152011Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading lfw-dataset, 117895655 bytes compressed
# [==================================================] 117895655 bytes downloaded
# Downloaded and uncompressed: lfw-dataset
# Data source import complete.

# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from mtcnn) (2.15.0)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from mtcnn) (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.25.2)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
import os
import shutil
import pandas as pd
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# %%
# Set the dataset path
dataset_path = '../input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled'

# Generate a list of (name, image count) tuples
names_images = []

for name in os.listdir(dataset_path):
    directory = os.path.join(dataset_path, name)
    if os.path.isdir(directory):
        images = [i for i in os.listdir(directory) if i.endswith('.jpg')]
        image_count = len(images)
        # Add to list if there are at least 25 images and store the actual image count
        if image_count >= 50:
            names_images.append((name, min(image_count, 50)))

# Update number_of_people to reflect the actual number of people with at least 25 images
number_of_people = len(names_images)
print(f"Number of people with at least 50 images: {number_of_people}")

# Create a DataFrame
lfw_allnames = pd.DataFrame(names_images, columns=['name', 'images'])

# Save the DataFrame to a CSV file
lfw_csv_path = '../input/lfw-dataset/lfw_allnames.csv'
lfw_allnames.to_csv(lfw_csv_path, index=False)

print(f"CSV file created at: {lfw_csv_path}")
# Out:
# Number of people with at least 50 images: 12
# CSV file created at: ../input/lfw-dataset/lfw_allnames.csv

# %%
# Define a new directory for experiments
new_dir_path = '../lfw-data-experiment'

# Create the new directory if it doesn't exist
if not os.path.exists(new_dir_path):
    os.makedirs(new_dir_path)

# Move the folders
for name, image_count in names_images:
    source_folder = os.path.join(dataset_path, name)
    destination_folder = os.path.join(new_dir_path, name)

    # Check if the destination folder already exists
    if os.path.exists(destination_folder):
        shutil.rmtree(destination_folder)

    # Move the folders
    if os.path.exists(source_folder):
        shutil.copytree(source_folder, destination_folder)
        # If there are more than 50 images, keep the first 50 and delete the rest
        images = sorted([i for i in os.listdir(destination_folder) if i.endswith('.jpg')])
        for img in images[50:]:  # Delete all images beyond the 25th
            os.remove(os.path.join(destination_folder, img))
    else:
        print(f"Folder for {name} does not exist in the dataset path.")

print("Folders moved successfully.")
# Out:
# Folders moved successfully.

# %%
# Read the dataset
people_data = os.listdir(new_dir_path)
people = []
for item in people_data:
    person_images = os.listdir(os.path.join(new_dir_path, item))
    for person_image in person_images:
        people.append((item, os.path.join(new_dir_path, item, person_image)))

# Create a DataFrame from the list of tuples
people_df = pd.DataFrame(people, columns=['person', 'path'])

# Convert labels to one-hot encoded labels
label_encoder = LabelEncoder()
labels = people_df['person'].values
int_encoded = label_encoder.fit_transform(labels)
y_onehot = to_categorical(int_encoded)

# Correct the size of the images to match the CNN input
im_size = 150

# Initialize lists to store the images and labels
images = []
labels = []

# Load and preprocess the images
for index, row in people_df.iterrows():
    img = cv2.imread(row['path'])
    img = cv2.resize(img, (im_size, im_size))
    images.append(img)
    labels.append(row['person'])

images = np.array(images)
images = images.astype('float32') / 255.0

# Shuffle and split the dataset
images, y_onehot = shuffle(images, y_onehot, random_state=1)
train_x, test_x, train_y_onehot, test_y_onehot = train_test_split(images, y_onehot, test_size=0.3, random_state=415)

# Check the shapes again to make sure they match
print("train_x shape:", train_x.shape)
print("train_y_onehot shape:", train_y_onehot.shape)
print("test_x shape:", test_x.shape)
print("test_y_onehot shape:", test_y_onehot.shape)
# Out:
# train_x shape: (420, 150, 150, 3)
# train_y_onehot shape: (420, 12)
# test_x shape: (180, 150, 150, 3)
# test_y_onehot shape: (180, 12)

# %%
import pandas as pd

# Create a DataFrame from the list of tuples
people_df = pd.DataFrame(people, columns=['person', 'path'])

# Count the number of samples for each person
person_count = people_df['person'].value_counts()

print("Total number of images of people in the dataset: ", len(people_df))
print("Samples in each category: ")
print(person_count)
# Out:
# Total number of images of people in the dataset:  600
# Samples in each category:
# person
# Junichiro_Koizumi    50
# Tony_Blair           50
# George_W_Bush        50
# Serena_Williams      50
# Jacques_Chirac       50
# Colin_Powell         50
# Jean_Chretien        50
# Ariel_Sharon         50
# Donald_Rumsfeld      50
# John_Ashcroft        50
# Gerhard_Schroeder    50
# Hugo_Chavez          50
# Name: count, dtype: int64

# %% [markdown]
# #Encoding

# %%
num_classes = len(np.unique(labels))
# im_shape=(im_size, im_size, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, ZeroPadding2D


alexnet = Sequential()

# Layer 1
alexnet.add(Conv2D(filters=96, kernel_size=(11, 11), strides=(4, 4), activation='relu', input_shape=(im_size, im_size, 3)))
alexnet.add(BatchNormalization())
alexnet.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

# Layer 2
alexnet.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding="same"))
alexnet.add(BatchNormalization())
alexnet.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

# Layer 3
alexnet.add(Conv2D(filters=384, kernel_size=(3, 3), strides=(1, 1), activation='relu', padding="same"))
alexnet.add(BatchNormalization())

# Layer 4
alexnet.add(Conv2D(filters=384, kernel_size=(3, 3), strides=(1, 1), activation='relu', padding="same"))
alexnet.add(BatchNormalization())

# Layer 5
alexnet.add(Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation='relu', padding="same"))
alexnet.add(BatchNormalization())
alexnet.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

# Layer 6
alexnet.add(Flatten())
alexnet.add(Dense(4096, activation='relu'))
alexnet.add(Dropout(0.5))

# Layer 7
alexnet.add(Dense(4096, activation='relu'))
alexnet.add(Dropout(0.5))

# Layer 8 - Output layer for binary classification
alexnet.add(Dense(num_classes, activation='softmax'))

# Compile the model
alexnet.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
alexnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 35, 35, 96)        34944
#
#  batch_normalization (Batch  (None, 35, 35, 96)        384
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 17, 17, 96)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 17, 17, 256)       614656
#
#  batch_normalization_1 (Bat  (None, 17, 17, 256)       1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 384)         885120
#
#  batch_normalization_2 (Bat  (None, 8, 8, 384)         1536
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 384)         1327488
#
#  batch_normalization_3 (Bat  (None, 8, 8, 384)         1536
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         884992
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 4096)              9441280
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 12)                49164
#
# =================================================================
# Total params: 30024460 (114.53 MB)
# Trainable params: 30021708 (114.52 MB)
# Non-trainable params: 2752 (10.75 KB)
# _________________________________________________________________

# %%
history = alexnet.fit(
    train_x,
    train_y_onehot,
    epochs=250,
    batch_size=32,
    validation_data=(test_x, test_y_onehot)
)
# Out:
# Epoch 1/250
# 14/14 [==============================] - 1s 76ms/step - loss: 0.8314 - accuracy: 0.8119 - val_loss: 5.2208 - val_accuracy: 0.3722
# Epoch 2/250
# 14/14 [==============================] - 1s 44ms/step - loss: 0.8996 - accuracy: 0.7619 - val_loss: 5.5326 - val_accuracy: 0.2611
# Epoch 3/250
# 14/14 [==============================] - 1s 50ms/step - loss: 0.5235 - accuracy: 0.8571 - val_loss: 4.7765 - val_accuracy: 0.3500
# Epoch 4/250
# 14/14 [==============================] - 1s 42ms/step - loss: 0.4976 - accuracy: 0.8524 - val_loss: 5.8134 - val_accuracy: 0.3389
# Epoch 5/250
# 14/14 [==============================] - 1s 38ms/step - loss: 0.5009 - accuracy: 0.8643 - val_loss: 3.4305 - val_accuracy: 0.4833
# Epoch 6/250
# 14/14 [==============================] - 1s 42ms/step - loss: 0.3964 - accuracy: 0.8786 - val_loss: 4.4739 - val_accuracy: 0.4556
# Epoch 7/250
# 14/14 [==============================] - 1s 43ms/step - loss: 0.3315 - accuracy: 0.9143 - val_loss: 4.3907 - val_accuracy: 0.4111
# Epoch 8/250
# 14/14 [==============================] - 1s 53ms/step - loss: 0.4719 - accuracy: 0.8786 - val_loss: 6.0029 - val_accuracy: 0.3611
# Epoch 9/250
# 14/14 [==============================] - 1s 37ms/step - loss: 0.4155 - accuracy: 0.8952 - val_loss: 3.5910 - val_accuracy: 0.4889
# Epoch 10/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.5413 - accuracy: 0.8548 - val_loss: 4.5128 - val_accuracy: 0.3667
# Epoch 11/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.4974 - accuracy: 0.8810 - val_loss: 6.0814 - val_accuracy: 0.3444
# Epoch 12/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.
250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0964 - accuracy: 0.9667 - val_loss: 3.1957 - val_accuracy: 0.5500
# Epoch 103/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0639 - accuracy: 0.9786 - val_loss: 2.7824 - val_accuracy: 0.5667
# Epoch 104/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0338 - accuracy: 0.9833 - val_loss: 3.3766 - val_accuracy: 0.5444
# Epoch 105/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0387 - accuracy: 0.9881 - val_loss: 3.4587 - val_accuracy: 0.5333
# Epoch 106/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0362 - accuracy: 0.9952 - val_loss: 3.2362 - val_accuracy: 0.5444
# Epoch 107/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 3.0885 - val_accuracy: 0.5444
# Epoch 108/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0321 - accuracy: 0.9857 - val_loss: 3.2972 - val_accuracy: 0.5333
# Epoch 109/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0745 - accuracy: 0.9786 - val_loss: 3.6387 - val_accuracy: 0.5167
# Epoch 110/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0215 - accuracy: 0.9952 - val_loss: 3.6589 - val_accuracy: 0.5111
# Epoch 111/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0157 - accuracy: 0.9929 - val_loss: 4.0966 - val_accuracy: 0.4611
# Epoch 112/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0565 - accuracy: 0.9857 - val_loss: 3.2947 - val_accuracy: 0.5167
# Epoch 113/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0058 - accuracy: 0.9976 - val_loss: 3.1201 - val_accuracy: 0.5444
# Epoch 114/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0370 - accuracy: 0.9881 - val_loss: 3.1952 - val_accuracy: 0.5556
# Epoch 115/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0049 - accuracy: 0.9976 - val_loss: 3.2354 - val_accuracy: 0.5500
# Epoch 116/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.1727 - val_accuracy: 0.5611
# Epoch 117/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 3.1626 - val_accuracy: 0.5722
# Epoch 118/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 2.9497 - val_accuracy: 0.5889
# Epoch 119/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.9674 - val_accuracy: 0.5944
# Epoch 120/250
# 14/14 [==============================] - 0s 32ms/step - loss: 5.7782e-04 - accuracy: 1.0000 - val_loss: 3.0581 - val_accuracy: 0.6056
# Epoch 121/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0100 - accuracy: 0.9976 - val_loss: 3.9185 - val_accuracy: 0.5444
# Epoch 122/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 3.5142 - val_accuracy: 0.5778
# Epoch 123/250
# 14/14 [==============================] - 1s 41ms/step - loss: 0.1122 - accuracy: 0.9857 - val_loss: 3.9445 - val_accuracy: 0.5944
# Epoch 124/250
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0515 - accuracy: 0.9857 - val_loss: 4.8739 - val_accuracy: 0.5389
# Epoch 125/250
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0300 - accuracy: 0.9952 - val_loss: 4.4104 - val_accuracy: 0.5556
# Epoch 126/250
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0179 - accuracy: 0.9905 - val_loss: 3.7599 - val_accuracy: 0.5500
# Epoch 127/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0577 - accuracy: 0.9833 - val_loss: 3.3304 - val_accuracy: 0.5556
# Epoch 128/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0289 - accuracy: 0.9929 - val_loss: 3.2577 - val_accuracy: 0.5500
# Epoch 129/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0265 - accuracy: 0.9905 - val_loss: 3.4042 - val_accuracy: 0.5000
# Epoch 130/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0227 - accuracy: 0.9952 - val_loss: 4.3395 - val_accuracy: 0.5056
# Epoch 131/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0285 - accuracy: 0.9881 - val_loss: 3.9300 - val_accuracy: 0.4889
# Epoch 132/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0685 - accuracy: 0.9905 - val_loss: 4.5345 - val_accuracy: 0.5278
# Epoch 133/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0537 - accuracy: 0.9905 - val_loss: 3.9725 - val_accuracy: 0.5778
# Epoch 134/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1932 - accuracy: 0.9905 - val_loss: 4.2714 - val_accuracy: 0.5333
# Epoch 135/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.
250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.4375 - accuracy: 0.9524 - val_loss: 7.9534 - val_accuracy: 0.4722
# Epoch 166/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.2187 - accuracy: 0.9452 - val_loss: 6.0793 - val_accuracy: 0.5056
# Epoch 167/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1352 - accuracy: 0.9762 - val_loss: 7.5082 - val_accuracy: 0.5278
# Epoch 168/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1148 - accuracy: 0.9738 - val_loss: 6.5688 - val_accuracy: 0.5222
# Epoch 169/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1255 - accuracy: 0.9762 - val_loss: 7.1668 - val_accuracy: 0.4778
# Epoch 170/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.5792 - accuracy: 0.9119 - val_loss: 6.4849 - val_accuracy: 0.4500
# Epoch 171/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.4150 - accuracy: 0.9310 - val_loss: 6.8996 - val_accuracy: 0.4167
# Epoch 172/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0970 - accuracy: 0.9810 - val_loss: 5.8068 - val_accuracy: 0.4833
# Epoch 173/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1508 - accuracy: 0.9762 - val_loss: 5.4420 - val_accuracy: 0.5444
# Epoch 174/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0574 - accuracy: 0.9810 - val_loss: 5.5393 - val_accuracy: 0.5056
# Epoch 175/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0618 - accuracy: 0.9905 - val_loss: 5.6771 - val_accuracy: 0.4889
# Epoch 176/250
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0863 - accuracy: 0.9738 - val_loss: 4.7833 - val_accuracy: 0.5222
# Epoch 177/250
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1637 - accuracy: 0.9762 - val_loss: 5.5986 - val_accuracy: 0.4944
# Epoch 178/250
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0461 - accuracy: 0.9881 - val_loss: 5.5854 - val_accuracy: 0.5111
# Epoch 179/250
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0446 - accuracy: 0.9833 - val_loss: 6.6460 - val_accuracy: 0.4611
# Epoch 180/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0109 - accuracy: 0.9976 - val_loss: 7.2997 - val_accuracy: 0.4889
# Epoch 181/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0491 - accuracy: 0.9905 - val_loss: 6.1308 - val_accuracy: 0.5167
# Epoch 182/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0173 - accuracy: 0.9881 - val_loss: 5.1767 - val_accuracy: 0.5444
# Epoch 183/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0933 - accuracy: 0.9857 - val_loss: 5.4326 - val_accuracy: 0.5167
# Epoch 184/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1316 - accuracy: 0.9833 - val_loss: 6.1803 - val_accuracy: 0.4722
# Epoch 185/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0801 - accuracy: 0.9786 - val_loss: 5.5172 - val_accuracy: 0.5167
# Epoch 186/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.4017 - accuracy: 0.9357 - val_loss: 4.7713 - val_accuracy: 0.4500
# Epoch 187/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.3989 - accuracy: 0.9333 - val_loss: 5.0398 - val_accuracy: 0.4778
# Epoch 188/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.2541 - accuracy: 0.9548 - val_loss: 4.5589 - val_accuracy: 0.5278
# Epoch 189/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.3905 - accuracy: 0.9310 - val_loss: 6.3609 - val_accuracy: 0.4333
# Epoch 190/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.4332 - accuracy: 0.9476 - val_loss: 4.6215 - val_accuracy: 0.4667
# Epoch 191/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1292 - accuracy: 0.9714 - val_loss: 5.9214 - val_accuracy: 0.4444
# Epoch 192/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.2146 - accuracy: 0.9762 - val_loss: 4.5016 - val_accuracy: 0.5056
# Epoch 193/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1699 - accuracy: 0.9667 - val_loss: 7.1731 - val_accuracy: 0.4333
# Epoch 194/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.2912 - accuracy: 0.9667 - val_loss: 5.9556 - val_accuracy: 0.4833
# Epoch 195/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1175 - accuracy: 0.9833 - val_loss: 6.5731 - val_accuracy: 0.4722
# Epoch 196/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1230 - accuracy: 0.9857 - val_loss: 6.0764 - val_accuracy: 0.4833
# Epoch 197/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0654 - accuracy: 0.9881 - val_loss: 5.1454 - val_accuracy: 0.4667
# Epoch 198/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1449 - accuracy: 0.9810 - val_loss: 4.9843 - val_accuracy: 0.5333
# Epoch 199/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.1438 - accuracy: 0.9833 - val_loss: 4.2596 - val_accuracy: 0.5444
# Epoch 200/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.1321 - accuracy: 0.9857 - val_loss: 4.1705 - val_accuracy: 0.5667
# Epoch 201/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1618 - accuracy: 0.9786 - val_loss: 4.5945 - val_accuracy: 0.4889
# Epoch 202/250
# 14/14 [==============================] - 0s 36ms/step - loss: 0.1142 - accuracy: 0.9690 - val_loss: 4.1901 - val_accuracy: 0.4611
# Epoch 203/250
# 14/14 [==============================] - 0s 36ms/step - loss: 0.1505 - accuracy: 0.9643 - val_loss: 4.6771 - val_accuracy: 0.4722
# Epoch 204/250
# 14/14 [==============================] - 1s 42ms/step - loss: 0.1277 - accuracy: 0.9810 - val_loss: 4.1278 - val_accuracy: 0.5278
# Epoch 205/250
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0242 - accuracy: 0.9905 - val_loss: 4.5659 - val_accuracy: 0.5778
# Epoch 206/250
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0248 - accuracy: 0.9952 - val_loss: 4.2137 - val_accuracy: 0.5611
# Epoch 207/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0153 - accuracy: 0.9976 - val_loss: 3.6903 - val_accuracy: 0.5444
# Epoch 208/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0960 - accuracy: 0.9857 - val_loss: 3.5200 - val_accuracy: 0.5500
# Epoch 209/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0465 - accuracy: 0.9905 - val_loss: 3.5897 - val_accuracy: 0.5611
# Epoch 210/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.7582 - val_accuracy: 0.5444
# Epoch 211/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0165 - accuracy: 0.9929 - val_loss: 4.3861 - val_accuracy: 0.5222
# Epoch 212/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0164 - accuracy: 0.9952 - val_loss: 4.4150 - val_accuracy: 0.5500
# Epoch 213/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0373 - accuracy: 0.9881 - val_loss: 4.5582 - val_accuracy: 0.5333
# Epoch 214/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 4.9819 - val_accuracy: 0.5278
# Epoch 215/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0277 - accuracy: 0.9881 - val_loss: 4.4772 - val_accuracy: 0.5500
# Epoch 216/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0587 - accuracy: 0.9929 - val_loss: 4.3771 - val_accuracy: 0.5556
# Epoch 217/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0096 - accuracy: 0.9976 - val_loss: 4.4562 - val_accuracy: 0.5278
# Epoch 218/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0327 - accuracy: 0.9952 - val_loss: 5.5721 - val_accuracy: 0.4944
# Epoch 219/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1349 - accuracy: 0.9881 - val_loss: 5.7010 - val_accuracy: 0.4833
# Epoch 220/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0170 - accuracy: 0.9952 - val_loss: 6.3825 - val_accuracy: 0.4722
# Epoch 221/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0478 - accuracy: 0.9810 - val_loss: 6.0637 - val_accuracy: 0.5278
# Epoch 222/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0455 - accuracy: 0.9881 - val_loss: 6.4991 - val_accuracy: 0.4833
# Epoch 223/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0362 - accuracy: 0.9952 - val_loss: 5.4472 - val_accuracy: 0.5667
# Epoch 224/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0048 - accuracy: 0.9976 - val_loss: 5.0924 - val_accuracy: 0.5611
# Epoch 225/250
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 7.8076 - val_accuracy: 0.4833
# Epoch 226/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0609 - accuracy: 0.9881 - val_loss: 8.6790 - val_accuracy: 0.4944
# Epoch 227/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1493 - accuracy: 0.9810 - val_loss: 5.1476 - val_accuracy: 0.5556
# Epoch 228/250
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0216 - accuracy: 0.9952 - val_loss: 4.2868 - val_accuracy: 0.5556
# Epoch 229/250
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0471 - accuracy: 0.9929 - val_loss: 4.8645 - val_accuracy: 0.5667
# Epoch 230/250
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0202 - accuracy: 0.9952 - val_loss: 5.1301 - val_accuracy: 0.5611
# Epoch 231/250
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0745 - accuracy: 0.9857 - val_loss: 5.8491 - val_accuracy: 0.5278
# Epoch 232/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.3440 - accuracy: 0.9667 - val_loss: 6.8765 - val_accuracy: 0.4611
# Epoch 233/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.3516 - accuracy: 0.9500 - val_loss: 6.3182 - val_accuracy: 0.4611
# Epoch 234/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1931 - accuracy: 0.9548 - val_loss: 5.3597 - val_accuracy: 0.5111
# Epoch 235/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1213 - accuracy: 0.9786 - val_loss: 6.7422 - val_accuracy: 0.5056
# Epoch 236/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1261 - accuracy: 0.9786 - val_loss: 5.4118 - val_accuracy: 0.5667
# Epoch 237/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0765 - accuracy: 0.9786 - val_loss: 5.6553 - val_accuracy: 0.5444
# Epoch 238/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1160 - accuracy: 0.9833 - val_loss: 5.2334 - val_accuracy: 0.5611
# Epoch 239/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.2325 - accuracy: 0.9619 - val_loss: 4.7134 - val_accuracy: 0.5444
# Epoch 240/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.2590 - accuracy: 0.9643 - val_loss: 6.4216 - val_accuracy: 0.4667
# Epoch 241/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0878 - accuracy: 0.9762 - val_loss: 5.0908 - val_accuracy: 0.5611
# Epoch 242/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1739 - accuracy: 0.9714 - val_loss: 9.8736 - val_accuracy: 0.4278
# Epoch 243/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.2027 - accuracy: 0.9619 - val_loss: 10.8090 - val_accuracy: 0.3944
# Epoch 244/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1886 - accuracy: 0.9714 - val_loss: 11.3178 - val_accuracy: 0.3722
# Epoch 245/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.2098 - accuracy: 0.9690 - val_loss: 6.5732 - val_accuracy: 0.5222
# Epoch 246/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1946 - accuracy: 0.9786 - val_loss: 5.9878 - val_accuracy: 0.5056
# Epoch 247/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1060 - accuracy: 0.9833 - val_loss: 5.1760 - val_accuracy: 0.5500
# Epoch 248/250
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0064 - accuracy: 0.9952 - val_loss: 5.8484 - val_accuracy: 0.5500
# Epoch 249/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0613 - accuracy: 0.9905 - val_loss: 5.7125 - val_accuracy: 0.5667
# Epoch 250/250
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0195 - accuracy: 0.9929 - val_loss: 6.1907 - val_accuracy: 0.5444

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])  # Now this line is active
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])  # And this line is active
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import cv2
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.models import load_model  # if you have a model to load, otherwise import your CNN architecture

# Assuming your CNN has been trained and you have the model loaded
# model = load_model('your_model.h5')  # Load your trained model

# Generate predictions
test_y_pred = alexnet.predict(test_x)
test_y_pred_classes = np.argmax(test_y_pred, axis=1)
test_y_true = np.argmax(test_y_onehot, axis=1)

# Print the confusion matrix
conf_matrix = confusion_matrix(test_y_true, test_y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Print classification report
print(classification_report(test_y_true, test_y_pred_classes, target_names=label_encoder.classes_))
# Out:
# 6/6 [==============================] - 0s 10ms/step
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.33      0.93      0.49        14
#      Colin_Powell       0.86      0.38      0.52        16
#   Donald_Rumsfeld       0.50      0.15      0.24        13
#     George_W_Bush       0.88      0.47      0.61        15
# Gerhard_Schroeder       0.60      0.50      0.55        18
#       Hugo_Chavez       0.56      0.69      0.62        13
#    Jacques_Chirac       0.28      0.45      0.34        11
#     Jean_Chretien       1.00      0.42      0.59        19
#     John_Ashcroft       0.64      0.50      0.56        18
# Junichiro_Koizumi       0.69      0.64      0.67        14
#   Serena_Williams       1.00      0.93      0.96        14
#        Tony_Blair       0.32      0.53      0.40        15
#
#          accuracy                           0.54       180
#         macro avg       0.64      0.55      0.55       180
#      weighted avg       0.66      0.54      0.55       180
